# %%
import pandas as pd
m=pd.read_csv('mtcars.csv')

# %%
m.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
m
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0   21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2   22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3   21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4   18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5   18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6   14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7   24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8   22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9   19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 11  16.4    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 12  17.3    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# ...

# %%
m['mpg'].plot.box()
# Out:
# <AxesSubplot:>

# %%
import numpy as pd
import statsmodels.formula.api as smapi

# %%
model1=smapi.ols(formula='mpg~wt',data=mt).fit()
print(model1.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3984\3815114856.py in <module>
# ----> 1 model1=smapi.ols(formula='mpg~wt',data=mt).fit()
#       2 print(model1.summary())
#
# NameError: name 'mt' is not defined

# %%
import seaborn as sns

# %%
sns.lmplot(x='wt',y='mpg',data=m)

# %%
m['mpg'].plotbox()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3984\2708263872.py in <module>
# ----> 1 m['mpg'].plotbox()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'plotbox'

# %%
import pandas as pd
m=pd.read_csv('mtcars.csv')

# %%
m
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0   21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2   22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3   21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4   18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5   18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6   14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7   24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8   22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9   19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 11  16.4    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 12  17.3    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# ...

# %%
import numpy as np
import statsmodels.formula.api as smapi

# %%
model1=smapi.ols(formula='mpg~wt + disp + hp',data=m).fit()
print(model1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.827
# Model:                            OLS   Adj. R-squared:                  0.808
# Method:                 Least Squares   F-statistic:                     44.57
# Date:                Wed, 05 Apr 2023   Prob (F-statistic):           8.65e-11
# Time:                        10:51:21   Log-Likelihood:                -74.321
# No. Observations:                  32   AIC:                             156.6
# Df Residuals:                      28   BIC:                             162.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     37.1055      2.111     17.579      0.000      32.782      41.429
# ...

# %%
import matplotlib.pyplot as plt

# %%
prediction=model1.predict()

# %%
plt.figure(figsize=(12,8))

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smapi

# %%
plt.plot(m['wt'],m['mpg'],'o')
plt.plot(m['wt'],prediction,'r')
plt.xlabel('wt')
plt.ylabel('mpg')
plt.title('mpg vs wt')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3984\245663282.py in <module>
#       1 plt.plot(m['wt'],m['mpg'],'o')
# ----> 2 plt.plot(m['wt'],prediction,'r')
#       3 plt.xlabel('wt')
#       4 plt.ylabel('mpg')
#       5 plt.title('mpg vs wt')
#
# NameError: name 'prediction' is not defined

# %%
model1=smapi.ols(formula='mpg~disp',data=m).fit()
print(model1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.718
# Model:                            OLS   Adj. R-squared:                  0.709
# Method:                 Least Squares   F-statistic:                     76.51
# Date:                Wed, 05 Apr 2023   Prob (F-statistic):           9.38e-10
# Time:                        10:58:37   Log-Likelihood:                -82.105
# No. Observations:                  32   AIC:                             168.2
# Df Residuals:                      30   BIC:                             171.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     29.5999      1.230     24.070      0.000      27.088      32.111
# ...

# %%
pred=model1.predict()
pred
# Out:
# array([23.00543556, 23.00543556, 25.1486218 , 18.96635381, 14.76241157,
#        20.32645276, 14.76241157, 23.55359666, 23.79676587, 22.69220065,
#        22.69220065, 18.23272467, 18.23272467, 18.23272467, 10.14631813,
#        10.64089957, 11.46520197, 26.35622482, 26.47987017, 26.66945973,
#        24.64991885, 16.49344661, 17.07045829, 15.17456277, 13.11380677,
#        26.34386028, 24.64167582, 25.68029685, 15.13334765, 23.62366236,
#        17.19410365, 24.61282524])

# %% [markdown]
# m.prediction()

# %%
m['prediction']=pred

# %%
m
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb  prediction
# 0   21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4   23.005436
# 1   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4   23.005436
# 2   22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1   25.148622
# 3   21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1   18.966354
# 4   18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2   14.762412
# 5   18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1   20.326453
# 6   14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4   14.762412
# 7   24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2   23.553597
# 8   22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2   23.796766
# 9   19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4   22.692201
# 10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4   22.692201
# ...

# %%
model1=smapi.ols(formula='mpg~disp+hp+drat+carb',data=m).fit()
print(model1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.810
# Model:                            OLS   Adj. R-squared:                  0.782
# Method:                 Least Squares   F-statistic:                     28.74
# Date:                Wed, 05 Apr 2023   Prob (F-statistic):           2.22e-09
# Time:                        11:10:26   Log-Likelihood:                -75.822
# No. Observations:                  32   AIC:                             161.6
# Df Residuals:                      27   BIC:                             169.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     17.8572      6.002      2.975      0.006       5.541      30.173
# ...
